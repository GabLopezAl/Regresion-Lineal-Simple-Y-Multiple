# %% [markdown]
# **Importar librerías**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mt
import seaborn as sns

# %%
# Leer archivo
df_mexico = pd.read_csv("Datos_limpios_Berlin.csv", encoding="MacRoman")
df_mexico.head()
# Out:
#    Unnamed: 0 last_scraped                                               name  \
# 0           0   18/09/2024                  130 sqm with a view on Mauer Park
# 1           1   18/09/2024                  light quiet beautiful 4 room flat
# 2           2   18/09/2024                Super Apartment in Berlin/Kreuzberg
# 3           3   18/09/2024  Rooftop apt w/ a view, 2 bedrooms/bathrooms, s...
# 4           4   18/09/2024  Room w/ balcony and private bathroom in nice area
#
#                                          description  \
# 0  An apartment of 130 sqm right in the heart of ...
# 1  We offer our 4 room apartment in Prenzlauer Be...
# 2  Our fantastic typical Berlin-style apartment i...
# 3  I am renting out my spacious, bright rooftop a...
# 4  I¬¨¬®¬¨‚Ä¢m offering a guest room with balcony...
#
#                                neighborhood_overview  \
# 0  Prenzlauer Berg is no doubt one of the most my...
# 1  Prenzlauer Berg is no doubt one of the most my...
# 2  Prenzlauer Berg is no doubt one of the most my...
# 3  Kastanienalle, Oderberger Strasse, Hackescher ...
# 4  The neighborhood "Prenzlauer Berg" is centrall...
#
#                                          picture_url  host_name  host_since  \
# 0  https://a0.muscache.com/pictures/miso/Hosting-...     Marine  14/11/2009
# 1  https://a0.muscache.com/pictures/caa048ba-e297...      Katja  08/11/2010
# 2  https://a0.muscache.com/pictures/176e2964-5ead...      Guidi  08/09/2010
# 3  https://a0.muscache.com/pictures/1135114/9db3c...    Stephan  08/12/2010
# 4  https://a0.muscache.com/pictures/miso/Hosting-...  Christian  07/12/2010
#
#                                           host_about  host_response_time  ...  \
# 0  I'm french but I have been living in Berlin si...      within an hour  ...
# 1           Designer who likes discovering the world  within a few hours  ...
# 2  Hi , I am Elena and I am looking forward to ho...  within a few hours  ...
# 3  Ich mag sch‚Äö√†√∂‚Äö√†√áne Dinge und Design. ...        within a day  ...
# 4  Christian from Berlin\n\nHi, I¬¨¬®¬¨‚Ä¢m a 52 ...  within a few hours  ...
#
#   number_of_reviews_ltm number_of_reviews_l30d review_scores_rating  \
# 0                  15.0                    0.0                 4.93
# 1                   7.0                    1.0                 4.84
# 2                   4.0                    0.0                 4.70
# 3                   0.0                    0.0                 4.75
# 4                  22.0                    0.3                 4.95
#
#   review_scores_accuracy review_scores_cleanliness review_scores_checkin  \
# 0                   4.95                      4.90                  4.97
# 1                   4.88                      4.79                  4.81
# 2                   4.68                      4.65                  4.82
# 3                   4.63                      4.50                  4.94
# 4                   4.95                      4.92                  4.95
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.94                   4.82                4.76
# 1                        4.91                   4.87                4.73
# 2                        4.82                   4.94                4.47
# 3                        4.63                   4.88                4.40
# 4                        4.92                   4.84                4.77
#
#   reviews_per_month
# 0              0.80
# 1              0.43
# 2              0.20
# 3              0.10
# 4              0.73
#
# [5 rows x 51 columns]

# %%
# Eliminar columna "Unnamed: 0"
df_mexico = df_mexico.drop(['Unnamed: 0'], axis = 1)
df_mexico.head()
# Out:
#   last_scraped                                               name  \
# 0   18/09/2024                  130 sqm with a view on Mauer Park
# 1   18/09/2024                  light quiet beautiful 4 room flat
# 2   18/09/2024                Super Apartment in Berlin/Kreuzberg
# 3   18/09/2024  Rooftop apt w/ a view, 2 bedrooms/bathrooms, s...
# 4   18/09/2024  Room w/ balcony and private bathroom in nice area
#
#                                          description  \
# 0  An apartment of 130 sqm right in the heart of ...
# 1  We offer our 4 room apartment in Prenzlauer Be...
# 2  Our fantastic typical Berlin-style apartment i...
# 3  I am renting out my spacious, bright rooftop a...
# 4  I¬¨¬®¬¨‚Ä¢m offering a guest room with balcony...
#
#                                neighborhood_overview  \
# 0  Prenzlauer Berg is no doubt one of the most my...
# 1  Prenzlauer Berg is no doubt one of the most my...
# 2  Prenzlauer Berg is no doubt one of the most my...
# 3  Kastanienalle, Oderberger Strasse, Hackescher ...
# 4  The neighborhood "Prenzlauer Berg" is centrall...
#
#                                          picture_url  host_name  host_since  \
# 0  https://a0.muscache.com/pictures/miso/Hosting-...     Marine  14/11/2009
# 1  https://a0.muscache.com/pictures/caa048ba-e297...      Katja  08/11/2010
# 2  https://a0.muscache.com/pictures/176e2964-5ead...      Guidi  08/09/2010
# 3  https://a0.muscache.com/pictures/1135114/9db3c...    Stephan  08/12/2010
# 4  https://a0.muscache.com/pictures/miso/Hosting-...  Christian  07/12/2010
#
#                                           host_about  host_response_time  \
# 0  I'm french but I have been living in Berlin si...      within an hour
# 1           Designer who likes discovering the world  within a few hours
# 2  Hi , I am Elena and I am looking forward to ho...  within a few hours
# 3  Ich mag sch‚Äö√†√∂‚Äö√†√áne Dinge und Design. ...        within a day
# 4  Christian from Berlin\n\nHi, I¬¨¬®¬¨‚Ä¢m a 52 ...  within a few hours
#
#   host_is_superhost  ... number_of_reviews_ltm number_of_reviews_l30d  \
# 0                 t  ...                  15.0                    0.0
# 1                 t  ...                   7.0                    1.0
# 2                 f  ...                   4.0                    0.0
# 3                 f  ...                   0.0                    0.0
# 4                 t  ...                  22.0                    0.3
#
#   review_scores_rating review_scores_accuracy review_scores_cleanliness  \
# 0                 4.93                   4.95                      4.90
# 1                 4.84                   4.88                      4.79
# 2                 4.70                   4.68                      4.65
# 3                 4.75                   4.63                      4.50
# 4                 4.95                   4.95                      4.92
#
#   review_scores_checkin review_scores_communication review_scores_location  \
# 0                  4.97                        4.94                   4.82
# 1                  4.81                        4.91                   4.87
# 2                  4.82                        4.82                   4.94
# 3                  4.94                        4.63                   4.88
# 4                  4.95                        4.92                   4.84
#
#   review_scores_value reviews_per_month
# 0                4.76              0.80
# 1                4.73              0.43
# 2                4.47              0.20
# 3                4.40              0.10
# 4                4.77              0.73
#
# [5 rows x 50 columns]

# %%
# Visualizar los tipos de habitacion que existen
df_mexico["room_type"].unique()
#df_entire_home_apt = df_berlin["room_type"].unique()
#df_entire_home_apt[0]
# Out:
# array(['Entire home/apt', 'Private room', 'Shared room', 'Hotel room'],
#       dtype=object)

# %%
# Graficar el scatter plot de las variables dependientes e independientes
from turtle import color

sns.scatterplot(x='price', y='room_type', color="blue", data=df_mexico)
sns.scatterplot(x='host_acceptance_rate', y='room_type', color="red", data=df_mexico)
# Out:
# <Axes: xlabel='price', ylabel='room_type'>

# %%
# Declaramos nuestras variables dependientes e independientes para nuestra regresion lineal simple
var_indep =  df_mexico[["price"]]
var_dep = df_mexico["room_type"]

# %%
# Se define model como la regresion lineal
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
# Entrenamos el modelo con las variables independientes (X) y la variable dependiente (y)
model.fit(X=var_indep, y=var_dep)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Entrenamos el modelo con las variables independientes (X) y la variable dependiente (y)
# ----> 2 model.fit(X=var_indep, y=var_dep)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:601, in LinearRegression.fit(self, X, y, sample_weight)
#     597 n_jobs_ = self.n_jobs
#     599 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 601 X, y = validate_data(
#     602     self,
#     603     X,
#     604     y,
#     605     accept_sparse=accept_sparse,
#     606     y_numeric=True,
#     607     multi_output=True,
#     608     force_writeable=True,
#     609 )
#     611 has_sw = sample_weight is not None
#     612 if has_sw:
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2961, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2959         y = check_array(y, input_name="y", **check_y_params)
#    2960     else:
# -> 2961         X, y = check_X_y(X, y, **check_params)
#    2962     out = X, y
#    2964 if not no_val_X and check_params.get("ensure_2d", True):
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1387, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1368 ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
#    1370 X = check_array(
#    1371     X,
#    1372     accept_sparse=accept_sparse,
#    (...)   1384     input_name="X",
#    1385 )
# -> 1387 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1389 check_consistent_length(X, y)
#    1391 return X, y
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1412, in _check_y(y, multi_output, y_numeric, estimator)
#    1410     _ensure_no_complex_data(y)
#    1411 if y_numeric and hasattr(y.dtype, "kind") and y.dtype.kind == "O":
# -> 1412     y = y.astype(np.float64)
#    1414 return y
#
# ValueError: could not convert string to float: 'Entire home/apt'
